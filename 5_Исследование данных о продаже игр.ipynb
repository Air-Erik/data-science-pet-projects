# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Эрнест, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провел отличную работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# Эрнест, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!\
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание; если таких замечаний меньше трех — проект может быть принят без их отработки.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделал огромную работу и проект получился впечатляющим:)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект еще лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# # Сборный проект №1
# # Исследование данных о продаже игр
# ### Описание проекта

# %% [markdown]
# Цель проекта - проанализировать данные о продажах компьютерных игр по всему миру за период до 2016 год, для выявления закономерностей и планирование продаж на 2017 год. На основе выводов данного исследования будут планироваться маркетинговые компании потенциально популярных продуктов. Также в ходе исследования необходимо провести проверку нескольких гипотез.
#
# Исходными данными выступает дата сет со следующими столбцами:
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# В ходе выполнения проекта будут реализованы следующие этапы:
# 1. Загрузка данных
# 1. Предобработка данных
# 1. Исследовательский анализ данных
# 1. Составление портрета пользователя каждого региона
# 1. Проверка гипотез
#
# В ходе этапа загрузки данных будет произведена загрузка исходного датсета и знакомство с данными. Проверка наличия пропусков в данных, знакомство с типами данных и анализ имен столбцов.
#
# На этапе предобработке данных будет повышено качество информации в исходном наборе данных. При необходимости будут изменены имена столбцов, преобразованы типы данных, обработаны пропуск в данных и подсчитаны суммарные продажи по регионам.
#
# На этапе исследовательского анализа данных будут рассмотрены продажи по годам и платформам. Также необходимо будет установить актуальный период, данные из которого будут использованы для дальнейшей работы. Будут сделаны выводы о влиянии оценок и отзывов на продажи. И наконец построено общее распределение игр по жанрам, для выявления наиболее коммерчески успешных жанров.
#
# При составлении портрета пользователя каждого региона необходимо описать наиболее популярные платформы и жанры для каждого региона. Сделать выводы и объяснить различия, если таковые будут найдены. Также необходимо выяснить влияет ли рейтинг ESRB на продажи в различных регионах
#
# На этапе проверки гипотез будут проверены 2 гипотезы:
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что написал введение!  </div>

# %% [markdown]
# ### Загрузка данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
data = pd.read_csv('/datasets/games.csv')

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# В исходном наборе данных есть некоторые проблемы. В названии столбцов и в типах данных. Также из данных выше следует что в наборе есть пропуски в столбцах `Name`, `Year_of_Release`, `Genre`, `Critic_Score`, `User_Score`, `Rating`. Необходимо выполнить предобработку данных

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Отлично, с данными познакомились!  </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Замена названия столбцов
#
# Необходимо привести название столбцов исходного датасета к нижнему регистру

# %%
data.columns = data.columns.str.lower()
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Также названия столбцов можно привести в нижнему регистру, если к `df.columns` применить метод `str.lower`</div>
#
# ```python
#
#                                     df.columns = df.columns.str.lower()
#
# ```

# %% [markdown]
# #### Преобразование типов данных
#
# Из знакомства с данными очевидно что изменить тип данных необходимо в столбце `year_of_release`. А в столбцах `critic_score`, `user_score`, `rating` необходимо проверить весь диапозон значений и уже после принимать решение об изменнеии типа данных

# %%
data = data.astype({'year_of_release': 'Int32'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int32
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: Int32(1), float64(5), object(5)
# memory usage: 1.4+ MB

# %%
display(data['critic_score'].unique())
display(data['user_score'].unique())
data['rating'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 35., 41., 36., 28., 31., 27., 26., 19., 23.,
#        24., 21., 17., 22., 13.])
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
# ...

# %% [markdown]
# Из вывода уникальных значений видно, что столбцy `critic_score` можно присвоить тип данных 'Int32'. Столбцу `rating` не получиться изменить тип данных.

# %%
data = data.astype({'critic_score': 'Int32'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int32
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   Int32
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: Int32(2), float64(4), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# Столбец `user_score` заслуживает отдельного пояснения. В нем встречается строковое значение 'tbd'. Которое дословно расшифровывается как "To Be Determined (будет определено)". Следовательно, данных еще нет, они будут определены в бедующем. Для исследования это значит что значения нет, вместо него можно поставить NaN. Для подтверждения выведем все строки, где встречается значение 'tbd'. Предположим что это может касаться игр вышедших только в последний год сбора данных.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Верное решение.</div>

# %%
tdb = data.query('user_score == "tbd"')

display(tdb)
tdb['year_of_release'].unique()
# Out:
#                                            name platform  year_of_release  \
# 119                               Zumba Fitness      Wii             2010
# 301              Namco Museum: 50th Anniversary      PS2             2005
# 520                             Zumba Fitness 2      Wii             2011
# 645                                uDraw Studio      Wii             2010
# 657    Frogger's Adventures: Temple of the Frog      GBA             <NA>
# ...                                         ...      ...              ...
# 16695                           Planet Monsters      GBA             2001
# 16697                          Bust-A-Move 3000       GC             2003
# 16698                          Mega Brain Boost       DS             2008
# 16704                                  Plushees       DS             2008
# 16706             Men in Black II: Alien Escape       GC             2003
#
#             genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %% [markdown]
# Предположение о последнем годе сбора данных не подтвердилось. В наборе есть данные за разные года. Значит ничего не остается как заменить 'tbd' на NaN

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# В replace лучше явно указать на что мы заменяем 'tbd'</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Добавил замену на NaN ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data['user_score'].replace(to_replace='tbd',value=np.nan, inplace=True)
data = data.astype({'user_score': 'float64'})

data['user_score'] = data['user_score'].round(2)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  Int32
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   Int32
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: Int32(2), float64(5), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Обработка пропусков

# %% [markdown]
# ##### Удаление пропусков которые невозможно обработать

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %%
data.query('name.isna() or genre.isna()')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN             1993   NaN      1.78      0.53      0.00
# 14244  NaN      GEN             1993   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score rating
# 659           0.08          <NA>         NaN    NaN
# 14244         0.00          <NA>         NaN    NaN

# %%
data.dropna(subset=['name', 'genre'], inplace=True)

# %% [markdown]
# Пропуски в годах релиза тоже немногочисленны. Их можно исключить без существенной потери качества набора данных. Заполнение пропусков не представляется возможным так как нет возможности получить данные для заполнения.

# %%
data.dropna(subset=['year_of_release'], inplace=True)

# %%
data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating             6676
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Заполнять пропуски в годах выпуска некорректно, некоторые игры выходили с одним и тем же названием в разные годы и на разных платформах.
#
# Строк с пропусками в годах выпуска не так много и их можно исключить, ведь они в любом случае не попадут в актуальный период.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Согласен, это я не учитывал. И в целом пропусков не так много. Поправил, строки с пропусками исключил ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ##### Обработка пропусков в оценках

# %% [markdown]
# Заполнить пропуски в оценках критиков и пользователей не представляется возможным. Связано это с тем что оценки не являются случайным набором данных, пропуски в которых можно заполнить медианным значением. Оценка это уже усредненного значение некоторого набора значений. В связи с этим пропущенные значения могут быть только исключены

# %% [markdown]
# Перед исключением проверим на какой период больше всего повлияет исключение подобного набора значений

# %%
scores = data.query('critic_score.isna() or user_score.isna()')['year_of_release'].value_counts().sort_index()
scores.plot()
plt.xlabel("Год")
plt.ylabel('Количество строк данных для исключения')
plt.title('Распределние исключаемых данных по годам')

data.query('critic_score.isna() or user_score.isna()')['name'].count()
# Out:
# 9550

# %% [markdown]
# Распределение удаляемых строк показывает что больше всего данных будет удалено за период с 2005 по 2010 год. Количество удаляемых данных составляет 9550. Считаю удаление такого количества данных плохим решением. Оставляю пропуски как есть. Буду учитывать их наличие при работе с оценками.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Заполнять пропуски в оценках неверное решение) Ошибка связана с тем, что данные по оценкам не являются набором случайных наблюдений. Если бы у нас была выборка всех оценок пользователей для одной игры (один пользователь поставил оценку 10, другой 1, третий 5), то пропуски мы могли бы заменить медианой.
#
# В нашем случае оценка уже является усредненным значением выборки оценок некоторого количества пользователей. Более того, можно найти примеры, когда оценки одной игры на различных платформах отличаются в два раза.
#
# Аналогичная ситуация и с рейтингами критиков.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Исключил попытку заполнения пропусков в этой категории данных. Сначала хотел исключить все пропуски, однако проанализировав количество исключаемых данных, а также их распределение по годам принял решение оставить пропуски. Исключу их на этапе работы с оценками если это будет необходимо ✔
# </div>

# %% [markdown]
# ##### Обработка пропусков в возрастном рейтинге

# %% [markdown]
# К сожалению пропуски в возрастном рейтинге не могут быть качественно обработаны опираясь на те данные что у нас есть. Они остануться в наборе данных

# %%
data.query('rating.isna()')['name'].count()
# Out:
# 6676

# %% [markdown]
# ##### Проверка на наличие дубликатов

# %% [markdown]
# Необходимо провести проверку на наличие явных дубликатов строк

# %%
data.duplicated().value_counts()
# Out:
# False    16444
# dtype: int64

# %% [markdown]
# Полных дубликатов строк не обнаружено. Однако имеет смысл провести проверку на наличие дубликатов строк совпадающих по названию, платформе и году релиза одновременно

# %%
data.duplicated(subset=['name', 'platform', 'year_of_release']).value_counts()
# Out:
# False    16443
# True         1
# dtype: int64

# %%
data[data.duplicated(subset=['name', 'platform', 'year_of_release'])]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16230  Madden NFL 13      PS3             2012  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 16230       0.0          0.0            83         5.5      E

# %%
data.drop_duplicates(subset=['name', 'platform', 'year_of_release'], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  Int32
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   Int32
#  9   user_score       7462 non-null   float64
#  10  rating           9767 non-null   object
# dtypes: Int32(2), float64(5), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Не увидел проверки на полные дубликаты строк. Это одно из обязательных действий при предобработке данных. Также необходимо сделать проверку на наличие неявных дубликатов (совпадающие по названию, платформе и году релиза одновременно).
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Добавил проверку. Нашел один дубликат, удалил его ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ##### Подсчет суммарных продаж

# %% [markdown]
# Для подсчета суммарного числа продаж необходимо сложить столбцы продаж в Америке, Европе, Японии и других регионах

# %%
data['sum_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Еще тут можно использовать метод `DataFrame.sum` с аргументом `axis=1`</div>
#
# ```python
#
#         df['total_sum'] = df[['value_1', 'value_2', 'value_3', 'value_4']].sum(axis=1)
#
# ```

# %% [markdown]
# ##### Исключенные данных с сумарными продажами менее 500 тыс. копий

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# С чем связано такое решение? Так мы искажаем данные. В исследовании мы должны опираться на актуальный период, а не на количество продаж.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Сделал это для исключения значений существенно влияющих на "ящик с усами". Окей оставляю эти значения. Изначально не посмотрел степень влияние этого решения на набор данных ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# #### Итоги предобработки данных

# %% [markdown]
# Итоги предобработки данных:
# * Изменены названия столбцов. Названия приведены к нижнему регистру
# * Преобразованы типы данных с учетом реальной информации записанной в датасете
# * Обработаны пропуски в данных
#     * Удалены 2 строки с пропусками в названии игры и жанре
#     * Удалены пропуски в годах релиза.
#     * Пропуски в оценках игр от критиков и пользователей оставлены без изменений. Восполнить их не представляется возможным, а исключение сильно ухудшит набор данных
# * Посчитаны суммарные продажи для каждой строки

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что делаешь промежуточные выводы!  </div>

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Количество игр по годам

# %% [markdown]
# Рассмотрим распределение количества выпущенных игр по годам. И определим примерный интервал, который будем использовать в дальнейшем для анализа и построение представлений о будущих продажах

# %%
data_year = data.pivot_table(index='year_of_release', values='name', aggfunc='count')

ax = data_year.plot()

plt.xlabel('Годы')
plt.ylabel('Количество игр')
plt.title('Распределение количества игр по годам')

data_year.sort_index(ascending=False).head(15)
# Out:
#                  name
# year_of_release
# 2016              502
# 2015              606
# 2014              581
# 2013              544
# 2012              652
# 2011             1136
# 2010             1255
# 2009             1426
# 2008             1427
# 2007             1197
# 2006             1006
# 2005              939
# 2004              762
# 2003              775
# 2002              829

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Гистограмма в данном случае не подходит. Сначала нужно сформировать сводную таблицу, посчитав количество релизов за каждый год, а затем построить график (линейный или барплот).
#     </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Гистограмму заменил на линейный график. Данные для графика получил сгруппировав исходный набор данных в сводную таблицу с подсчетом количества релизов в каждом году ✔
# </div>

# %% [markdown]
# Из распределения и описательных статистик видно, что основной набор данных собран за период от 2003 до 2011. Так как нас интересует будущее то для анализа можно использовать интервал от 2003 до 2016. В таком случае мы захватим основной массив данных и учтем актуальные тренды. Интревал анализа будет уточнен в дальнейшем.

# %% [markdown]
# #### Изменеие продаж по платформам

# %% [markdown]
# Для дальнейшей работы необходимо вычислить суммарные продажи по каждой платформе, а также установить срок появления и исчезновения игровых платформ. Для этого создадим сводную таблицу. В качестве индексов возьмем названия платформ, подсчитаем суммарные продажи. Для определения срока жизни платформы, можем определить минимальную и максимальные даты выхода игр на тех или иных платформах.

# %%
platform_data = data.pivot_table(index='platform', 
                                 values=['sum_sales', 'year_of_release'], 
                                 aggfunc={'sum_sales': 'sum', 
                                          'year_of_release' : ['min', 'max']})
platform_data.columns = ['sum_sales', 'max_year', 'min_year']
platform_data
# Out:
#           sum_sales max_year min_year
# platform
# 2600          86.48     1989     1980
# 3DO            0.10     1995     1994
# 3DS          257.81     2016     2011
# DC            15.95     2008     1998
# DS           802.78     2013     1985
# GB           254.43     2001     1988
# GBA          312.88     2007     2000
# GC           196.73     2007     2001
# GEN           28.35     1994     1990
# GG             0.04     1992     1992
# N64          218.01     2002     1996
# NES          251.05     1994     1983
# NG             1.44     1996     1993
# PC           255.76     2016     1985
# PCFX           0.03     1996     1996
# PS           727.58     2003     1994
# PS2         1233.56     2011     2000
# PS3          931.33     2016     2006
# PS4          314.14     2016     2013
# PSP          289.53     2015     2004
# PSV           53.81     2016     2011
# SAT           33.59     1999     1994
# SCD            1.86     1994     1993
# ...

# %% [markdown]
# Исключим из дальнейшего анализа платформы с продажами менее 10 млн копий. Так как эти платформы нельзя назвать массовыми и срок жизни таких платформ достаточно короткий. И отсортируем таблицу по убыванию

# %%
platform_data = platform_data.query('sum_sales > 10')
platform_data = platform_data.sort_values(by='sum_sales', ascending=False)

# %% [markdown]
# Топ 12 платформ с наибольшими суммарными продажами

# %%
index_pl = platform_data.index[:12]
index_pl = index_pl.to_list()
index_pl
# Out:
# ['PS2',
#  'X360',
#  'PS3',
#  'Wii',
#  'DS',
#  'PS',
#  'PS4',
#  'GBA',
#  'PSP',
#  '3DS',
#  'PC',
#  'GB']

# %% [markdown]
# ##### Срок жизни платформы

# %% [markdown]
# Для определения срока жизни платформы вычтем из максимального значения года минимальное. Получим продолжительности жизни игровой платформы

# %%
platform_data['live_years'] = (platform_data['max_year'] - platform_data['min_year'] + 1)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Такой подход не очень корректный. Если платформа существовала, например в 2010, 2011 и 2012 годах, то у тебя получится 2012 - 2010 = 2, хотя должно быть 3 года</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Добавил единицу к общему времени жизни платформы ✔
# </div>

# %% [markdown]
# Для уточнения диапазона анализируемых данных по годам, построим график распределения и вычислим медианное значение жизни игровых платформ

# %%
platform_data['live_years'].hist(bins=31)

plt.xlabel('Срок жизни платформы')
plt.ylabel('Количество платформ')
plt.title('Распределение платформ по срокам их жизни')

display(platform_data)
print('Медианное значение жизни платформ: ', platform_data['live_years'].median())
# Out:
#           sum_sales max_year min_year live_years
# platform
# PS2         1233.56     2011     2000         12
# X360         961.24     2016     2005         12
# PS3          931.33     2016     2006         11
# Wii          891.18     2016     2006         11
# DS           802.78     2013     1985         29
# PS           727.58     2003     1994         10
# PS4          314.14     2016     2013          4
# GBA          312.88     2007     2000          8
# PSP          289.53     2015     2004         12
# 3DS          257.81     2016     2011          6
# PC           255.76     2016     1985         32
# GB           254.43     2001     1988         14
# XB           251.57     2008     2000          9
# NES          251.05     1994     1983         12
# N64          218.01     2002     1996          7
# SNES         200.04     1999     1990         10
# GC           196.73     2007     2001          7
# XOne         159.32     2016     2013          4
# ...

# %% [markdown]
# Уточним временой интревал, который будет рассматриваться для построения прогнозов на 2017 год. C 2007 до 2016 года.

# %% [markdown]
# ##### Разбивка продаж по платформам

# %% [markdown]
# Наибольшее суммарные продажи у следующих платформ. Если анализировать данные за весь период

# %%
fig, ax = plt.subplots(figsize=(10, 7))
x_arr = platform_data['sum_sales']
y_arr = platform_data.index

ax.barh(y_arr, x_arr)
plt.xlabel("Суммарные продажи")
plt.ylabel("Платформы")
plt.title('Суммарны продажи всех игр по платформам за весь период')
ax.invert_yaxis()
ax.grid(True)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец ,что подписываешь графики и оси! </div>

# %% [markdown]
# ##### Распределение продаж по годам для самых распространённых платформ

# %% [markdown]
# Распределение продаж по годам для 12 самых распространённых платформ

# %%
i = 0

fig, ax = plt.subplots(ncols=3, nrows=4, figsize=(15, 20))

for row in range(4):
    for col in range(3):
        y_arr = data.query('platform ==  @index_pl[@i]')['sum_sales']
        x_arr = data.query('platform ==  @index_pl[@i]')['year_of_release']

        ax[row, col].bar(x_arr, y_arr)
        ax[row, col].set(xlabel='Годы', ylabel='Суммарное количество продаж', title=index_pl[i])
        i = i + 1

# %% [markdown]
# Распределения подтверждают теорию о жизненом цикле платформы в 10 лет. PC выбивается из общего тренда в силу специфики своей категории.
# Также здесь можно отметить что с момента релиза платформа достегает пика или плато продаж не менее чем за 3 года.

# %% [markdown]
# #### Актуальный период

# %% [markdown]
# Как установлено ранее, медианное время жизни платформы составляет 10 лет. Эту догадку подтверждают графики распределения продаж по платформам и годам. Однако для дальнейшего анализа нам потребуются данные по платформам, возникшим не ранее 3 лет назад по отношению к 2017 году, на который нам нужно сделать прогноз и запланировать рекламные кампании. Так мы сможем выделить успешные платформы, которые на 2017 год будут находиться в периоде финального роста или выйдут на плато.
#
# Создадим новый набор данных с продажами только за актуальный период

# %%
data_act = data.query('year_of_release >= 2013')
data_act
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 42                Grand Theft Auto V      PS4             2014        Action
# ...                              ...      ...              ...           ...
# 16703               Strawberry Nauts      PSV             2016     Adventure
# 16707               Aiyoku no Eustia      PSV             2014          Misc
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Актуальный период выбрал больше чем нужно. В этот срез попадут уже неактуальные платформы.
#
# Учитывая высокую динамичность рынка, мы можем сделать вывод, что для дальнейшего анализа нам потребуются данные по платформам, возникшим не ранее 3 лет назад по отношению к 2017 году, на который нам нужно сделать прогноз и запланировать рекламные кампании. Так мы сможем выделить успешные платформы, которые на 2017 год будут находиться в периоде финального роста или выйдут на плато. </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Ограничил период 2013 годом ✔
# </div>

# %% [markdown]
# #### Определение растущих и падающих платформ за актуальный период

# %% [markdown]
# Определяем список актуальных платформ. Для посмотрим суммарные продажи за период с 2013 по 2016 год. Отбросим платформы с очень низкими продажами. Построим графики

# %%
platform_data_act = data_act.pivot_table(index='platform', 
                                         values=['sum_sales', 'na_sales', 'eu_sales', 'jp_sales'], 
                                         aggfunc='sum')

platform_data_act = platform_data_act.query('sum_sales > 5').sort_values(by='sum_sales', ascending=False)
platform_data_act
# Out:
#           eu_sales  jp_sales  na_sales  sum_sales
# platform
# PS4         141.09     15.96    108.74     314.14
# PS3          67.81     23.35     63.50     181.43
# XOne         51.59      0.34     93.12     159.32
# 3DS          30.96     67.81     38.20     143.25
# X360         42.52      0.51     81.66     136.80
# WiiU         19.85     10.88     29.21      64.63
# PC           25.36      0.00     11.11      39.43
# PSV           6.10     18.59      5.04      32.99
# Wii           5.93      0.05      6.56      13.66

# %%
fig, ax = plt.subplots(figsize=(10, 7))
x_arr = platform_data_act['sum_sales']
y_arr = platform_data_act.index

ax.barh(y_arr, x_arr)
plt.xlabel("Суммарные продажи")
plt.ylabel("Платформы")
plt.title('Суммарные продажи всех игр по платформам за период с 2013 по 2016')
ax.invert_yaxis()
ax.grid(True)

# %% [markdown]
# ##### Распределние продаж по годам

# %% [markdown]
# Список актуальных платформ

# %%
index_pl_act = platform_data_act.index.to_list()
index_pl_act
# Out:
# ['PS4', 'PS3', 'XOne', '3DS', 'X360', 'WiiU', 'PC', 'PSV', 'Wii']

# %% [markdown]
# Построим распределние суммарного колличество продаж по актуальным платформам. Это необходимо чтобы понять какие платформы являются лидерами продаж, а также оценить динамику. Чтобы не делать ставки на платформы которые доживают последние годы.

# %%
j = 0

fig_1 = plt.figure(figsize=(15, 15))
axs = fig_1.subplots(ncols=3, nrows=3)

for row in range(3):
    for col in range(3):
        y_arr_act = data_act.query('platform ==  @index_pl_act[@j]')['sum_sales']
        x_arr_act = data_act.query('platform ==  @index_pl_act[@j]')['year_of_release']

        axs[row, col].bar(x_arr_act, y_arr_act)
        axs[row, col].set(xlabel='Годы', ylabel='Суммарное количество продаж', title=index_pl_act[j])
        j = j + 1

# %% [markdown]
# PS4, XOne, 3DS, WiiU, PC - список актуальных платформ которые показывают удовлетворительную динамику продаж. Это значит что они могут быть рассмотренные как целивые для маркейтинговой компании 2017 года. При выборе актуальных платформ учитывается не только динамика, но и абсолютные цифры продаж. Поэтому в список не попала PSV
#
# Остальные платформы либо уже закончили свой жизненый цикл. Либо показывают критическое снижение продаж сигнализирующее о близкойм конце жизненого цикла.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# А все ли перечисленные платформы можно назвать потенциально прибыльными? Например у PSV за 2015 и 2016 годы вообще нет продаж</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# PSV действительно показывает неудовлетворительную динамику продаж в абсолютном выражении. Исключил ее ✔
# </div>

# %% [markdown]
# #### "Ящик с усами" по продажам в разбивке по платформам

# %% [markdown]
# Построим ящик с усами для каждой платформы чтобы визуализировать разброс суммарного числа продаж внутри каждой платформы. Для более точной оценки выведем описательный статистики

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Далее нам нужно анализировать все данные из актуального периода, без дополнительных фильтраций по платформам. Это позволит нам убедиться в правильности выбора перспективных платформ и не допустить ошибок.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
box1 = data_act.boxplot(by='platform', column='sum_sales', figsize=(12,7))

plt.xlabel('Платформы')
plt.ylabel('Сумарные продажи')
plt.title('Ящик с усами для суммарных продаж по платформам за актуальный период')

box2 = data_act.boxplot(by='platform', column='sum_sales', figsize=(12,7))

box2.set_ylim(0, 1.75)
plt.xlabel('Платформы')
plt.ylabel('Сумарные продажи')
plt.title('Ящик с усами для суммарных продаж по платформам за актуальный период')
# Out:
# Text(0.5, 1.0, 'Ящик с усами для суммарных продаж по платформам за актуальный период')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Не забывай подписывать названия для графиков и оси
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Тут лучше построить две визуализации. Одну не ограничивая продажи, чтобы рассмотреть выбросы, а на другой ограничить диапазон значений продаж ,чтобы отчетливо рассмотреть сами боксплоты. </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Подписал оси. Сделал два гарфика. Взял все данные за актуальный период ✔
# </div>

# %%
data_act.groupby(['platform'])['sum_sales'].describe().sort_values(by='count')
# Out:
#           count      mean       std   min     25%    50%     75%    max
# platform
# DS          8.0  0.192500  0.172026  0.03  0.0675  0.150  0.2525   0.51
# Wii        23.0  0.593913  0.915432  0.01  0.0450  0.180  0.7550   3.58
# PSP        67.0  0.052239  0.059768  0.01  0.0150  0.020  0.0700   0.24
# WiiU      115.0  0.562000  1.038778  0.01  0.0600  0.200  0.5950   7.09
# X360      186.0  0.735484  1.663275  0.01  0.0800  0.265  0.7950  16.27
# PC        189.0  0.208624  0.352304  0.01  0.0300  0.080  0.2300   3.05
# XOne      247.0  0.645020  1.036139  0.01  0.0600  0.220  0.6850   7.39
# 3DS       303.0  0.472772  1.381347  0.01  0.0400  0.090  0.2800  14.60
# PS3       345.0  0.525884  1.451939  0.01  0.0400  0.150  0.5100  21.05
# PSV       358.0  0.092151  0.153816  0.01  0.0200  0.040  0.1100   1.96
# PS4       392.0  0.801378  1.609456  0.01  0.0600  0.200  0.7300  14.63

# %% [markdown]
# Исходя из данных представленных выше можно сделать следующие выводы:
# * медианное значение продаж одной игры находится в диапазоне от 0.04 до 0.265 млн копий
# * успешные игры являются выбросами
# * платформы описанные нами как потенциально прибыльные имеют больший размах выборки

# %% [markdown]
# #### Влияние отзывов на продажи

# %% [markdown]
# Установим пресутсвуют ли связь между отзывами и продажами. Построим диаграммы рассеивания и посчитаем корреляцию.
# Для анализа выберем самую популярную платформу - PS3, PS4, XOne, X360
#
# Помним что в предобработке данных мы оставили пропуск в оценках. Сформируем два набора данных за актуальный период. В одном исключим пропуски в оценках критиков, во втором для пользователей

# %%
data_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2233 entries, 16 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2233 non-null   object
#  1   platform         2233 non-null   object
#  2   year_of_release  2233 non-null   Int32
#  3   genre            2233 non-null   object
#  4   na_sales         2233 non-null   float64
#  5   eu_sales         2233 non-null   float64
#  6   jp_sales         2233 non-null   float64
#  7   other_sales      2233 non-null   float64
#  8   critic_score     991 non-null    Int32
#  9   user_score       1192 non-null   float64
#  10  rating           1256 non-null   object
#  11  sum_sales        2233 non-null   float64
# dtypes: Int32(2), float64(6), object(4)
# memory usage: 213.7+ KB

# %%
critic_score_data_act = data_act.dropna(subset=['critic_score'])
user_score_data_act = data_act.dropna(subset=['user_score'])

display(critic_score_data_act.info())
user_score_data_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 991 entries, 16 to 16692
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             991 non-null    object
#  1   platform         991 non-null    object
#  2   year_of_release  991 non-null    Int32
#  3   genre            991 non-null    object
#  4   na_sales         991 non-null    float64
#  5   eu_sales         991 non-null    float64
#  6   jp_sales         991 non-null    float64
#  7   other_sales      991 non-null    float64
#  8   critic_score     991 non-null    Int32
#  9   user_score       976 non-null    float64
#  10  rating           954 non-null    object
#  11  sum_sales        991 non-null    float64
# dtypes: Int32(2), float64(6), object(4)
# memory usage: 94.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1192 entries, 16 to 16692
# Data columns (total 12 columns):
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# Все основные методы pandas по-умолчанию убирают пропуски при расчетах (среднее, медиана, корреляция и тд). Поэтому их можно не удалять.</div>

# %%
list_platform = ['PS3', 'PS4', 'XOne', 'X360']

for i in list_platform:
    
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    
    critic = critic_score_data_act.query('platform == @i')
    user = user_score_data_act.query('platform == @i')
    
    axs[0].scatter(x=critic['critic_score'], y=critic['sum_sales'])
    axs[0].set_title(f'Диаграмма рассеивания оценок критиков для {i}')
    axs[0].set_xlabel('Оценка критиков')
    axs[0].set_ylabel('Суммарные продажи')
    
    axs[1].scatter(x=user['user_score'], y=user['sum_sales'])
    axs[1].set_title(f'Диаграмма рассеивания оценок пользователей для {i}')
    axs[1].set_xlabel('Оценка пользователей')
    axs[1].set_ylabel('Суммарные продажи')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# `scatterplot` здесь был бы нагляднее</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
for i in list_platform:
    critic = critic_score_data_act.query('platform == @i')
    user = user_score_data_act.query('platform == @i')
    
    k_p_critic = critic['critic_score'].astype('float').corr(critic['sum_sales'])
    k_p_user = user['user_score'].astype('float').corr(user['sum_sales'])
    
    print(f'Коэффициент Пирсона для оценки критиков по платформе {i}:', round(k_p_critic, 3))
    print(f'Коэффициент Пирсона для оценки пользователей по платформе {i}:', round(k_p_user, 3))
    print()
# Out:
# Коэффициент Пирсона для оценки критиков по платформе PS3: 0.334
# Коэффициент Пирсона для оценки пользователей по платформе PS3: 0.002
#
# Коэффициент Пирсона для оценки критиков по платформе PS4: 0.407
# Коэффициент Пирсона для оценки пользователей по платформе PS4: -0.032
#
# Коэффициент Пирсона для оценки критиков по платформе XOne: 0.417
# Коэффициент Пирсона для оценки пользователей по платформе XOne: -0.069
#
# Коэффициент Пирсона для оценки критиков по платформе X360: 0.35
# Коэффициент Пирсона для оценки пользователей по платформе X360: -0.012

# %% [markdown]
# Исходя из диаграмм рассеяния и коэфициентов Пирсона можно сделать следующие выводы:
# * Между оценкой критиков и продажами есть слабая корреляция для проверенных платформ
# * Между оценкой пользователей и продажами нет корреляции для проверенных платформ

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Чтобы сделать итоговый вывод о зависимости продаж от оценок, нам нужно рассмотреть еще как минимум 3 платформы подобным образом (как PS3). Так как код будет повторяться, его можно выполнять в цикле или написать небольшую функцию.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Сделал анализ для нескольких платформ. Упаковал все в циклы ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# #### Зависимость продаж от жанра

# %% [markdown]
# Посмотрим на распределение игр по жанрам. Можно ли сделать вывод о том что одни жанры прибыльнее других? Для этого рассмотрим среднее и медианные значения продаж игр в разбивке по жанрам

# %%
genre_mean_data_act = data_act.pivot_table(index='genre', 
                                      values=['sum_sales', 'na_sales', 'eu_sales', 'jp_sales'], 
                                      aggfunc='mean')
genre_mean_data_act = genre_mean_data_act.sort_values(by='sum_sales', ascending=False)
display(genre_mean_data_act)

genre_median_data_act = data_act.pivot_table(index='genre', 
                                      values=['sum_sales', 'na_sales', 'eu_sales', 'jp_sales'], 
                                      aggfunc='median')
genre_median_data_act = genre_median_data_act.sort_values(by='sum_sales', ascending=False)
genre_median_data_act
# Out:
#               eu_sales  jp_sales  na_sales  sum_sales
# genre
# Shooter       0.469840  0.035348  0.586845   1.245882
# Sports        0.282804  0.025280  0.305000   0.703972
# Platform      0.210541  0.064730  0.245135   0.576081
# Role-Playing  0.126610  0.174795  0.158904   0.499623
# Racing        0.237529  0.027059  0.152471   0.469294
# Fighting      0.106875  0.095625  0.194375   0.441375
# Action        0.154217  0.052859  0.164556   0.420196
# Misc          0.129290  0.059355  0.177355   0.405290
# Simulation    0.176129  0.072903  0.078387   0.350968
# Puzzle        0.058824  0.069412  0.048824   0.186471
# Strategy      0.075357  0.031607  0.058571   0.180000
# Adventure     0.033673  0.023755  0.029143   0.096490
#               eu_sales  jp_sales  na_sales  sum_sales
# genre
# Shooter          0.190      0.00     0.200      0.450
# Sports           0.050      0.00     0.080      0.240
# Platform         0.080      0.00     0.090      0.225
# ...

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
x_arr = genre_mean_data_act['sum_sales']
y_arr = genre_mean_data_act.index

axs[0].barh(y_arr, x_arr)
axs[0].set_xlabel("Среднее значение продаж")
axs[0].set_ylabel("Жанр")
axs[0].set_title('Среднее продажи всех игр по жанрам за период с 2013 по 2016')
axs[0].invert_yaxis()
axs[0].grid(True)

x_arr = genre_median_data_act['sum_sales']
y_arr = genre_median_data_act.index

axs[1].barh(y_arr, x_arr)
axs[1].set_xlabel("Медианное значение продаж")
axs[1].set_ylabel("Жанр")
axs[1].set_title('Медианные продажи всех игр по жанрам за период с 2013 по 2016')
axs[1].invert_yaxis()
axs[1].grid(True)

# %% [markdown]
# Исходя из данных выше можно сделать вывод, что 3 самых прибыльных жанра это `Shooter` `Sports` и `Platform`

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Определять прибыльность жанров только по суммарным продажам не совсем корректно, нужно еще учитывать соотношение с количеством выпущенных игр. А лучше сразу рассматривать медианные значения продаж, они являются наиболее объективным показателем прибыльности, так как менее подвержены влиянию выбросов (а в игровой индустрии их достаточно много за счет продаж очень популярных и хитовых игр)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Учел замечания ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# #### Итоги исследовательского анализа данных
# В ходе исследовательского анализа данных было установлено следующие:
# * С ходом времени количество игр увеличивается
# * Основной 75% данных сосредоточены "справа" с 2002 года и позднее
# * Медианное время жизни платформы 10 лет
# * Распределение продаж по платформам подтверждает данную цифру. Исключение платформа PC в силу своей специфики
# * Больше всего продано игр на PS2, X360 и PS3
# * Построенные распределения суммарного количества проданных игр по годам для 12 самых популярных платформ за весь период наблюдения. Для подтверждения времени жизни платформ
# * Определен актуальный период данных с 2013 по 2016 год
# * Построено распределение суммарного количества проданных игр по годам для 12 самых популярных платформ за актуальный период. Исходя из этих данных сформирован список перспективных платформ в 2017 году.
# * Построен ящик с усами для всех актуальных платформ на основе него сделаны следующие выводы:
#     * медианное значение продаж одной игры находится в диапазоне от 0.04 до 0.265 млн копий
#     * успешные игры являются выбросами
#     * платформы описанные нами как потенциально прибыльные имеют больший размах выборки
# * На основе диаграмм рассеяния и коэффициента корреляции сделаны следующе выводы:
#     * Между оценкой критиков и продажами есть слабая корреляция
#     * Между оценкой пользователей и продажами нет корреляции
# * Продажи сильно зависят от жанра

# %% [markdown]
# ### Портрет пользователя каждого региона

# %% [markdown]
# Для создания портрета пользователя каждого региона необходимо определить самые популярные платформы, жанры и рейтинги для каждого из регионов. Делать это удобнее всего с помощью круговых диаграмм и количественных показателей

# %% [markdown]
# #### Самые популярные платформы (топ-5)

# %% [markdown]
# Рассмотрим сначала абсолютное распределение по платформам для 3 регионов. На основании него можно сделать вывод об абсолютном вкладе того или иного региона в продажи платформы

# %%
regions = ('na_sales', 'eu_sales', 'jp_sales')

fig, ax = plt.subplots(figsize=(10, 7))
x_arr = platform_data_act['na_sales']
y_arr = platform_data_act.index

ax.barh(y_arr, x_arr)

x_arr = platform_data_act['eu_sales']
y_arr = platform_data_act.index

ax.barh(y_arr, x_arr)

x_arr = platform_data_act['jp_sales']
y_arr = platform_data_act.index

ax.barh(y_arr, x_arr)

plt.xlabel("Суммарные продажи")
plt.ylabel("Платформы")
plt.title('Суммарные продажи всех игр по платформам за период с 2007 по 2016 в регионе NA, EU, JP')
ax.invert_yaxis()
ax.legend(regions)
ax.grid(True)

# %% [markdown]
# Далее рассмотри относительные распределения внутри каждого из регионов

# %%
j = 0
list_regions = ['na_sales', 'eu_sales', 'jp_sales']

fig, axs = plt.subplots(1, 3, figsize=(19, 7))

for i in list_regions:
    
    platform = platform_data_act.sort_values(by=i, ascending=False)
    
    first_rows = platform.head(5)
    merged_row = pd.DataFrame(platform.iloc[5:].sum(axis=0)).T
    merged_row.index = ['Other']

    platform = pd.concat([first_rows, merged_row])
    list_platform = platform.index.to_list()
    
    axs[j].pie(platform[i].values, labels=list_platform, autopct='%1.1f%%', 
               colors=['#96B6C5', '#ADC4CE', '#EEE0C9', '#F1F0E8', '#7FC7D9', '#365486'])
    axs[j].set_title(f'Соотношение продаж\n между платформами для {i[0:2].upper()} региона')
    j += 1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Нужно стараться, чтобы цвета на диаграмме не повторялись, это может ввести в заблуждение.
#
# Для подбора цветов я использую [этот отличный сайт](https://colorhunt.co/palettes/pastel)
#
# Если значений, отображаемых на графике, более 6, то использовать круговую диаграмму не рекомендуется. Здесь лучше выделить топ-5, а остальные платформы объединить в отдельную категорию.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Все три диаграммы можно расположить рядом друг с другом, если предварительно построить для них фигуру с помощью
#
# `fig, axs = plt.subplots(1, 3, figsize=(19, 7))`  </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Учел замечания ✔
# </div>

# %% [markdown]
# ##### Различия между платформами

# %% [markdown]
# Для NA региона преобладающей является PS4 - 24.9%. Далее идут XOne, X360, PS3, 3DS.
# Для EU региона преобладающей является PS4 - 36.1%. Далее идут PS3, XOne, X360, 3DS.
# Для JP региона преобладающей является 3DS - 49.2%. Далее идут PS3, PSV, PS4, WiiU.
#
# Исходя из данных можно сделать следующие выводы:
# * Пользователи из NA и EU регионов отдают предпочтения одинаковому набору платформ
# * Пользователи из NA и EU регионов отдают предпочтене PS4
# * Пользователи из NA предпочитают платформы X360 и XOne вместо PS3 и PS4
# * Пользователи из EU наоборот отдают предпочтение PS3 и PS4 вместо X360 и XOne
# * Наибольшие продажи в регионах NA и EU составляют как актуальныне так и заканчивающие свой жизненый цикл платформы
# * Пользователи из JP региона отдают предпочтение уникальному набору платформ. Это можно обосновать спецификой региона.
# * Пользователи из JP региона предпочитают 3DS
# * Пользователи из JP региона полностью игнорируют X360 и XOne
# * Наибольшие продажи в регионе JP приходятся на актуальную платформу

# %% [markdown]
# #### Самые популярные жанры (топ-5)

# %%
fig, ax = plt.subplots(figsize=(10, 7))
x_arr = genre_mean_data_act['na_sales']
y_arr = genre_mean_data_act.index

ax.barh(y_arr, x_arr)

x_arr = genre_mean_data_act['eu_sales']
y_arr = genre_mean_data_act.index

ax.barh(y_arr, x_arr)

x_arr = genre_mean_data_act['jp_sales']
y_arr = genre_mean_data_act.index

ax.barh(y_arr, x_arr)

plt.xlabel("Суммарные продажи")
plt.ylabel("Платформы")
plt.title('Суммарные продажи всех игр по жанрам за период с 2007 по 2016 в регионе NA, EU, JP')
ax.invert_yaxis()
ax.legend(list_regions)
ax.grid(True)

# %%
j = 0

fig, axs = plt.subplots(1, 3, figsize=(19, 7))

for i in list_regions:
    
    genre = genre_mean_data_act.sort_values(by=i, ascending=False)

    
    first_rows = genre.head(5)
    merged_row = pd.DataFrame(genre.iloc[5:].sum(axis=0)).T
    merged_row.index = ['Other']

    genre = pd.concat([first_rows, merged_row])
    
    list_genre = genre.index.to_list()
    
    genre[i] = genre[i].astype(float)
    
    axs[j].pie(genre[i].values, labels=list_genre, autopct='%1.1f%%', 
               colors=['#96B6C5', '#ADC4CE', '#EEE0C9', '#F1F0E8', '#7FC7D9', '#365486'], normalize=True)
    axs[j].set_title(f'Соотношение продаж\n между жанрами для {i[0:2].upper()} региона')
    j += 1

# %% [markdown]
# ##### Различия между жанрами

# %% [markdown]
# Для NA региона преобладающий жанр это Shooter - 26.7%. Далее идут Sports, Platform, Fighting, Misc.
# Для EU региона преобладающий жанр это Shooter - 24.1%. Далее идут Sports, Racing, Platform, Simulator.
# Для EU региона преобладающий жанр это Role-Playing - 25.4%. Далее идут Fighting, Simulator, Puzzle, Platform.
#
# Исходя из данных можно сделать следующие выводы:
# * Пользователи из NA и EU регионов имеют похожие предпочтения в жанрах
# * Больше половины пользователей из NA и EU регионов предпочитают игры в жанрах Shooter, Sport, Platform
# * Пользователи из JP региона имеют уникальные предпочтения
# * Больше половины пользователей из JP региона предпочитают игры в жанрах Role-Playing, Fighting, Simulator

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в отдельном регионе

# %%
data_act['rating'].fillna(value='No_rating', inplace=True)
rating_data_act = data_act.pivot_table(index='rating', 
                                      values=['sum_sales', 'na_sales', 'eu_sales', 'jp_sales'], 
                                      aggfunc='sum')
rating_data_act
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#            eu_sales  jp_sales  na_sales  sum_sales
# rating
# E             83.36     15.14     79.05     200.16
# E10+          42.69      5.89     54.24     115.39
# M            145.32     14.11    165.21     371.68
# No_rating     78.91     85.05     89.42     276.84
# T             41.95     20.59     49.79     126.62

# %%
fig, ax = plt.subplots(figsize=(10, 7))
x_arr = rating_data_act['na_sales']
y_arr = rating_data_act.index

ax.barh(y_arr, x_arr)

x_arr = rating_data_act['eu_sales']
y_arr = rating_data_act.index

ax.barh(y_arr, x_arr)

x_arr = rating_data_act['jp_sales']
y_arr = rating_data_act.index

ax.barh(y_arr, x_arr)

plt.xlabel("Суммарные продажи")
plt.ylabel("Платформы")
plt.title('Суммарные продажи всех игр по жанрам за период с 2007 по 2016 в регионе NA, EU, JP')
ax.invert_yaxis()
ax.legend(regions)
ax.grid(True)

# %%
j = 0
list_regions = ['na_sales', 'eu_sales', 'jp_sales']

fig, axs = plt.subplots(1, 3, figsize=(19, 7))

for i in list_regions:
    
    rating = rating_data_act.sort_values(by=i, ascending=False)
    list_rating = rating.index.to_list()
    
    axs[j].pie(rating[i].values, labels=list_rating, autopct='%1.1f%%', 
               colors=['#96B6C5', '#ADC4CE', '#EEE0C9', '#F1F0E8', '#365486'])
    axs[j].set_title(f'Соотношение продаж\n между рейтингами для {i[0:2].upper()} региона')
    j += 1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# А если заполнить пропуски в рейтингах каким-нибудь единым значением, означающим отсутствие рейтинга, то можно будет увидеть интересную особенность)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Учел замечания ✔
# </div>

# %% [markdown]
# ##### Различия между рейтингами

# %% [markdown]
# Для NA региона преобладающий рейтинг это M - 37.7%. Далее идут No_rating, E, E10+, T.
# Для EU региона преобладающий рейтинг это M - 37.0%. Далее идут E, No_rating, E10+, T.
# Для JP региона преобладающий рейтинг это No_rating - 60.4%. Далее идут T, E, M, E10+.
#
# Исходя из данных можно сделать следующие выводы:
# * Пользователи из NA и EU регионов имеют похожие предпочтения в рейтингах
# * Пользователи из NA и EU регионов в равной степени выбирают рейтинг M и E
# * Пользователи из JP региона имеют уникальные предпочтения
# * Игры с пропущенным рейтингом имеют наибольшую поплярность в регионе JP. Возможно это связано с особенностями лицензирования для данного региона

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> В Японии есть своя рейтинговая система CERO  </div>

# %% [markdown]
# #### Итоги построения портрета пользователя

# %% [markdown]
# В ходе составления портрета пользователя выявлены следующие закономерности для каждого региона:
#
# **NA Регион**
# * Популярные платформы утрачивающие актуальность: X360, PS3
# * Актуальные популярные платформы: PS4, XOne, 3DS
# * Доминирующая платформа: PS4, XOne
# * Предпочитаемые жанры: Shooter, Sport, Platform
# * Преобладающие рейтинги: M, E и игры без рейтинга
#
# **EU Регион**
# * Популярные платформы утрачивающие актуальность:  PS3, X360
# * Актуальные популярные платформы: PS4, XOne, 3DS
# * Доминирующая платформа: PS4
# * Предпочитаемые жанры: Shooter, Sport, Platform
# * Преобладающие рейтинги: M, E и игры без рейтинга
#
# **JP Регион**
# * Популярные платформы утрачивающие актуальность:  PS3, PSV
# * Актуальные популярные платформы: 3DS, PS4, WiiU
# * Доминирующая платформа: 3DS
# * Предпочитаемые жанры: Role-Playing, Fighting, Simulator
# * Преобладающие рейтинги: игры без рейтинга (60%)
#
# При составлении маркетинговой компании на год необходимо учитывать специфику региона и характерного для него поведения пользователей.

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# #### Гипотеза №1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# Формулировка гипотезы: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые. Уровень статистической значимости примем 0.05
#
# Нулевая гипотеза: Среднее значение пользовательского рейтинга для платформы XOne равно среднему значению пользовательского рейтинга для платформы PС
#
# Альтернативная гипотеза: Среднее значение пользовательского рейтинга для платформы XOne не равно среднему значению пользовательского рейтинга для платформы PС

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что формулируешь гипотезы перед проверкой </div>

# %%
alpha = 0.05

xone_data_act = data_act.query('platform == "XOne"')['user_score'].dropna()
pc_data_act = data_act.query('platform == "PC"')['user_score'].dropna()

results = st.ttest_ind(xone_data_act, pc_data_act)
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу\n') 

print('Средняя оценка пользователей для XOne: ', round(xone_data_act.mean(), 4))
print('Средняя оценка пользователей для PC: ', round(pc_data_act.mean(), 4))
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу
#
# Средняя оценка пользователей для XOne:  6.5214
# Средняя оценка пользователей для PC:  6.2697

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Кстати, можно не удалять пропуски из сравниваемых выборок, а передать в ttest_ind аргумент nan_policy с нужным значением, тогда они будут игнорироваться. Подробнее можно почитать [здесь](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html) </div>

# %% [markdown]
# Не получилось отвергнуть нулевую гипотезу. Однако это не значит что она истина. Средняя оценка пользователей для XOne и PC отличается статистически не значимо.

# %% [markdown]
# #### Гипотеза №2. Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# Формулировка гипотезы: Средние пользовательские рейтинги жанров Action и Sports разные. Уровень статистической значимости примем 0.05
#
# Нулевая гипотеза: Среднее значение пользовательского рейтинга для жанра Action равно среднему значению пользовательского рейтинга для жанра Sports
#
# Альтернативная гипотеза: Среднее значение пользовательского рейтинга для жанра Action не равно среднему значению пользовательского рейтинга для жанра Sports

# %%
alpha = 0.05

action_data_act = data_act.query('genre == "Action"')['user_score'].dropna()
sport_data_act = data_act.query('genre == "Sports"')['user_score'].dropna()

results = st.ttest_ind(action_data_act, sport_data_act)
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу\n') 

print('Средняя оценка пользователей для XOne: ', round(action_data_act.mean(), 4))
print('Средняя оценка пользователей для PC: ', round(sport_data_act.mean(), 4))
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу
# Средняя оценка пользователей для XOne:  6.8375
# Средняя оценка пользователей для PC:  5.2381

# %% [markdown]
# Отвергаем нулевую гипотезу в пользу альтернативной. Различие средних значений пользовательского рейтинга жанров Action и Sports статистически значимо.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Гипотезы верно проработаны! </div>

# %% [markdown]
# #### Итоги проверки гипотез
# Для проверки гипотез был применен единый подход с использованием Т-теста и оценки значения статистики p-value. Проверялась гипотеза о равенстве среднего значения двух совокупностей данных.
#
# Обе гипотезы формулировались исходя из равенства средних значений. Однако результаты сравнения интерпретировались по-разному.
#
# Для первой гипотезы при невозможности отвержения нулевой гипотезы формулировка оказывалась верной. Для второй гипотезы наоборот. Если нулевая гипотеза отвергается, то формулировка верна.
#
# По результатам проверки установлено что:
# * Средняя оценка пользователей для XOne и PC отличается статистически не значимо
# * Различие средних значений пользовательского рейтинга жанров Action и Sports статистически значимо.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Целью проекта было выявления закономерностей в продажах компьютерных игр по всему миру за период до 2016 год, для планирования продаж на 2017 год. На основе выводов данного исследования будут планироваться маркетинговые компании потенциально популярных продуктов. Также в ходе исследования необходимо провести проверку нескольких гипотез.
#
# В ходе работы была выполнена **предобработка данных**. На данном этапе произведены следующие манипуляции с данными:
# * Изменены названия столбцов. Названия приведены к нижнему регистру
# * Преобразованы типы данных с учетом реальной информации записанной в датасете
# * Обработаны пропуски в данных
#     * Удалены 2 строки с пропусками в названии игры и жанре
#     * Удалены пропуски в годах релиза.
#     * Пропуски в оценках игр от критиков и пользователей оставлены без изменений. Восполнить их не представляется возможным, а исключение сильно ухудшит набор данных
# * Посчитаны суммарные продажи для каждой строки
#
# На этапе **исследовательского анализа** сделаны следующие выводы:
# * С ходом времени количество игр увеличивается
# * Основной 75% данных сосредоточены "справа" с 2002 года и позднее
# * Медианное время жизни платформы 10 лет
# * Распределение продаж по платформам подтверждает данную цифру. Исключение платформа PC в силу своей специфики
# * Больше всего продано игр на PS2, X360 и PS3
# * Построенные распределения суммарного количества проданных игр по годам для 12 самых популярных платформ за весь период наблюдения. Для подтверждения времени жизни платформ
# * Определен актуальный период данных с 2013 по 2016 год
# * Построено распределение суммарного количества проданных игр по годам для 12 самых популярных платформ за актуальный период. Исходя из этих данных сформирован список перспективных платформ в 2017 году.
# * Построен ящик с усами для всех актуальных платформ на основе него сделаны следующие выводы:
#     * медианное значение продаж одной игры находится в диапазоне от 0.04 до 0.265 млн копий
#     * успешные игры являются выбросами
#     * платформы описанные нами как потенциально прибыльные имеют больший размах выборки
# * На основе диаграмм рассеяния и коэффициента корреляции сделаны следующе выводы:
#     * Между оценкой критиков и продажами есть слабая корреляция
#     * Между оценкой пользователей и продажами нет корреляции
# * Продажи сильно зависят от жанра
#
# В ходе составления портрета пользователя выявлены следующие закономерности для каждого региона:
#
# **NA Регион**
# * Популярные платформы утрачивающие актуальность: X360, PS3
# * Актуальные популярные платформы: PS4, XOne, 3DS
# * Доминирующая платформа: PS4, XOne
# * Предпочитаемые жанры: Shooter, Sport, Platform
# * Преобладающие рейтинги: M, E и игры без рейтинга
#
# **EU Регион**
# * Популярные платформы утрачивающие актуальность:  PS3, X360
# * Актуальные популярные платформы: PS4, XOne, 3DS
# * Доминирующая платформа: PS4
# * Предпочитаемые жанры: Shooter, Sport, Platform
# * Преобладающие рейтинги: M, E и игры без рейтинга
#
# **JP Регион**
# * Популярные платформы утрачивающие актуальность:  PS3, PSV
# * Актуальные популярные платформы: 3DS, PS4, WiiU
# * Доминирующая платформа: 3DS
# * Предпочитаемые жанры: Role-Playing, Fighting, Simulator
# * Преобладающие рейтинги: игры без рейтинга (60%)
#
# Также были привереды две **гипотезы**, результаты проверки следующие:
# * Средняя оценка пользователей для XOne и PC отличается статистически не значимо
# * Различие средних значений пользовательского рейтинга жанров Action и Sports статистически значимо.
#
# На основе этих данных можно дать следующие рекомендации при построении маркетинговой компании:
# 1. Количество проданных игр будет существенно различаться в зависимости от региона. Однако в абсолютных цифрах продаж регион NA лидирует. Также стабильно большие цифры продаж показывает EU регион. Регион JP имеет свою специфику и имеет меньший объем продаж
# 1. Актуальный период определен с 2013 по 2016 годы. Для исключения платформ, жизненный цикл которых подходит к концу в 2017 году, были построены графики распределения продаж для каждой из платформ по годам.
# 1. Конец анализируемого периода приходится на время окончания жизненного цикла самых популярных платформ. Поэтому был сформирован список актуальных платформ проекты для которых будут приносить основную выручку в 2017 году. Это PS4, 3DS, PC, XOne, WiiU.
# 1. Только отзывы критиков имеют слабое влияние на продажи. Отзывы пользователей не имеют влияния на продажи
# 1. Жанры существенно влияют на продажи в целом. Топ 3 самых кассовых жанра за актуальный период: Shooter, Sport, Platform
# 1. Супер прибыльные продукты скорее исключения из правил, основную кассу делают среднее продукты за счет своей массовости. Имеет смысл учитывать это в маркетинговой компании
# 1. К каждому региону необходим свой подход. Если в EU и NA различия не существенны. То для рынка JP жанры как и платформы существенно отличаются
# 1. Стоит учитывать что на рынках EU и JP есть ярко выраженная доминирующая платформа. На рынке NA между платформами наблюдается большая конкуренция
# 1. Есть аномалия в предпочтениях игроков в JP регионе. Лидируют игры с пропуском в значении рейтинга. Возможно это связано с особенностями лицензирования в регионе

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Хороший резюмирующий вывод! Молодец, что не забыл дать рекомендации на 2017 год.
#
# В целом проект получился очень даже хорошим. Ты уверенно обращаешься с данными, отлично их анализируешь и строишь прекрасные визуализации! Нужно только переопределить актуальный период, подправить несколько замечаний и будет супер!
#
# **Хочу обратить твое внимание на то, что после исправления замечаний в некоторых пунктах исследования могут измениться результаты, поэтому нужно будет подкорректировать выводы.**</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Учел все замечания. Поправил вывод ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично👍  </div>
